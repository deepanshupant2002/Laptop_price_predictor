# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('laptop_data.csv')
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df['Company'].value_counts()
# Out:
# Lenovo       297
# Dell         297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Mediacom       7
# Razer          7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Google         3
# Fujitsu        3
# Chuwi          3
# LG             3
# Huawei         2
# Name: Company, dtype: int64

# %%
df['TypeName'].value_counts()
# Out:
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Netbook                25
# Name: TypeName, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0       Inches          Price
# count  1303.00000  1303.000000    1303.000000
# mean    651.00000    15.017191   59870.042910
# std     376.28801     1.426304   37243.201786
# min       0.00000    10.100000    9270.720000
# 25%     325.50000    14.000000   31914.720000
# 50%     651.00000    15.600000   52054.560000
# 75%     976.50000    15.600000   79274.246400
# max    1302.00000    18.400000  324954.720000

# %%
df = df.drop(columns='Unnamed: 0')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df['Ram'] = df['Ram'].str.replace("GB","")

# %%
df['Weight'] = df['Weight'].str.replace('kg',"")

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# ...

# %%
df['Ram'] = df['Ram'].astype('int32')
df['Weight'] = df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %%
sns.displot(df["Price"],kind='kde')

# %%
sns.displot(df['Company'])

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.displot(df['Inches'])

# %%
df.corr()
# Out:
#           Inches       Ram    Weight     Price
# Inches  1.000000  0.237993  0.827631  0.068197
# Ram     0.237993  1.000000  0.383874  0.743007
# Weight  0.827631  0.383874  1.000000  0.210370
# Price   0.068197  0.743007  0.210370  1.000000

# %%
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# IPS Panel 1366x768                                 7
# Touchscreen 2560x1440                              7
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2256x1504                              6
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# ...

# %%
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x: 1 if 'Touchscreen' in x else 0)

# %%
df.sample()
# Out:
#     Company  TypeName  Inches   ScreenResolution                         Cpu  \
# 813    Dell  Notebook    15.6  Full HD 1920x1080  Intel Core i7 7500U 2.7GHz
#
#      Ram   Memory                      Gpu       OpSys  Weight     Price  \
# 813    8  1TB HDD  Nvidia GeForce GT 940MX  Windows 10    1.98  51202.08
#
#      Touchscreen
# 813            0

# %%
df['Touchscreen'].value_counts()
# Out:
# 0    1111
# 1     192
# Name: Touchscreen, dtype: int64

# %%
sns.barplot(x = df['Touchscreen'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='Touchscreen', ylabel='Price'>

# %%
df['IPS'] = df['ScreenResolution'].apply(lambda x: 1 if 'IPS' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
sns.barplot(x=df['IPS'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='IPS', ylabel='Price'>

# %%
df.corr()
# Out:
#                Inches       Ram    Weight     Price  Touchscreen       IPS
# Inches       1.000000  0.237993  0.827631  0.068197    -0.361735 -0.114804
# Ram          0.237993  1.000000  0.383874  0.743007     0.116984  0.206623
# Weight       0.827631  0.383874  1.000000  0.210370    -0.294620  0.016967
# Price        0.068197  0.743007  0.210370  1.000000     0.191226  0.252208
# Touchscreen -0.361735  0.116984 -0.294620  0.191226     1.000000  0.150512
# IPS         -0.114804  0.206623  0.016967  0.252208     0.150512  1.000000

# %%
new = df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
df['x_reso'] = new[0]
df['y_reso'] = new[1]

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df['x_reso'] = df['x_reso'].str.findall(r'(\d+\.?\d+)').apply(lambda x: x[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df['x_reso'] = df['x_reso'].astype('int')
df['y_reso'] = df['y_reso'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  x_reso            1303 non-null   int32
#  14  y_reso            1303 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(7)
# ...

# %%
df.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# x_reso         0.556529
# y_reso         0.552809
# Name: Price, dtype: float64

# %%
df['PPI'] = (((df['x_reso']**2) + (df['y_reso']**2))**0.5/df['Inches']).astype('float')

# %%
df.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# x_reso         0.556529
# y_reso         0.552809
# PPI            0.473487
# Name: Price, dtype: float64

# %%
df['PPI']
# Out:
# 0       226.983005
# 1       127.677940
# 2       141.211998
# 3       220.534624
# 4       226.983005
#            ...
# 1298    157.350512
# 1299    276.053530
# 1300    111.935204
# 1301    100.454670
# 1302    100.454670
# Name: PPI, Length: 1303, dtype: float64

# %%
df.drop(columns = ['ScreenResolution','Inches','x_reso','y_reso'],inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI
# 0  226.983005
# 1  127.677940
# ...

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz     190
# Intel Core i7 7700HQ 2.8GHz    146
# Intel Core i7 7500U 2.7GHz     134
# Intel Core i7 8550U 1.8GHz      73
# Intel Core i5 8250U 1.6GHz      72
#                               ...
# AMD A12-Series 9700P 2.5GHz      1
# Intel Core i3 6100U 2.1GHz       1
# Intel Core M 7Y30 1.0GHz         1
# Intel Core i5 7200U 2.50GHz      1
# Intel Core i5 2.0GHz             1
# Name: Cpu, Length: 118, dtype: int64

# %%
df['Cpu_Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.sample(10)
# Out:
#       Company   TypeName                          Cpu  Ram  \
# 274   Toshiba   Notebook   Intel Core i7 6500U 2.5GHz    8
# 1293   Lenovo   Notebook  Intel Core i7 6700HQ 2.6GHz    8
# 505    Lenovo   Notebook   Intel Core i5 7200U 2.5GHz    8
# 1096     Dell   Notebook   Intel Core i5 7200U 2.5GHz    8
# 726      Dell   Notebook   Intel Core i5 8250U 1.6GHz    8
# 607    Lenovo   Notebook   Intel Core i5 7200U 2.5GHz    6
# 680       MSI     Gaming  Intel Core i5 7300HQ 2.5GHz    8
# 691    Lenovo   Notebook   Intel Core i5 7200U 2.5GHz    4
# 146        HP  Ultrabook     Intel Core M 6Y75 1.2GHz    8
# 1190   Lenovo     Gaming  Intel Core i5 7300HQ 2.5GHz    8
#
#                     Memory                      Gpu       OpSys  Weight  \
# 274              500GB HDD      Nvidia GeForce 930M  Windows 10    2.20
# 1293               1TB HDD  Nvidia GeForce GTX 960M  Windows 10    2.60
# 505              256GB SSD    Intel HD Graphics 620  Windows 10    1.44
# ...

# %%
df['Processor'] = df['Cpu'].apply(lambda x:x.split()[-1:]).apply(lambda x:x[0])

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI       Cpu_Name Processor
# ...

# %%
df["Processor"] = df['Processor'].str.replace('GHz','')

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI       Cpu_Name Processor
# ...

# %%
df['Processor'] = df['Processor'].astype('float')

# %%
df.corr()['Price']
# Out:
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# PPI            0.473487
# Processor      0.430293
# Name: Price, dtype: float64

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu_Brand'] = df['Cpu_Name'].apply(fetch_processor)

# %%
df.sample(10)
# Out:
#      Company            TypeName                                   Cpu  Ram  \
# 253   Lenovo  2 in 1 Convertible            Intel Core i7 8550U 1.8GHz    8
# 932       HP            Notebook  Intel Celeron Dual Core N3060 1.6GHz    4
# 285     Acer            Notebook            Intel Core i7 7500U 2.7GHz   12
# 1241    Asus           Ultrabook            Intel Core i7 6500U 2.5GHz    8
# 277     Acer            Notebook            Intel Core i7 8550U 1.8GHz    8
# 44      Dell  2 in 1 Convertible            Intel Core i5 8250U 1.6GHz   12
# 85      Dell              Gaming           Intel Core i7 7700HQ 2.8GHz   16
# 1290    Dell            Notebook            Intel Core i3 7100U 2.4GHz    6
# 1085      HP            Notebook            Intel Core i5 6200U 2.3GHz    4
# 777     Acer            Notebook            Intel Core i3 7100U 2.4GHz    4
#
#                     Memory                         Gpu       OpSys  Weight  \
# ...

# %%
sns.barplot(x=df['Cpu_Brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Cpu','Cpu_Name'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  IPS         PPI  Processor  \
# 0  macOS    1.37   71378.6832            0    1  226.983005        2.3
# 1  macOS    1.34   47895.5232            0    0  127.677940        1.8
# 2  No OS    1.86   30636.0000            0    0  141.211998        2.5
# 3  macOS    1.83  135195.3360            0    1  220.534624        2.7
# 4  macOS    1.37   96095.8080            0    1  226.983005        3.1
#
#        Cpu_Brand
# 0  Intel Core i5
# 1  Intel Core i5
# 2  Intel Core i5
# ...

# %%
sns.barplot(x=df['Ram'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='Ram', ylabel='Price'>

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 1TB SSD                           14
# 512GB SSD +  1TB HDD              14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 256GB SSD +  500GB HDD             2
# 1TB SSD +  1TB HDD                 2
# 512GB Flash Storage                2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)

df["first"]= new[0]
df["first"]=df["first"].str.strip()

df["second"]= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '')

df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '')

df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
                 'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)

# %%
df.sample(10)
# Out:
#        Company  TypeName  Ram               Memory                      Gpu  \
# 354    Toshiba  Notebook   16              512 SSD      Nvidia GeForce 930M
# 323         HP  Notebook    8             1000 HDD   Intel UHD Graphics 620
# 991         HP  Notebook    4  128 SSD +  1000 HDD           AMD Radeon 520
# 1174    Lenovo  Notebook    8             1000 HDD     Nvidia GeForce 940MX
# 206       Dell  Notebook    6             1000 HDD    Intel HD Graphics 620
# 97        Dell  Notebook    4              256 SSD       AMD Radeon R5 M430
# 556   Mediacom  Notebook    4     32 Flash Storage        Intel HD Graphics
# 375         HP  Notebook    4              256 SSD            AMD Radeon R5
# 622       Dell  Notebook    4             1000 HDD           AMD Radeon 530
# 1279    Lenovo  Notebook    8             1000 HDD  Nvidia GeForce GTX 960M
#
#            OpSys  Weight       Price  Touchscreen  IPS         PPI  Processor  \
# ...

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df.corr()['Price']
# Out:
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# IPS              0.252208
# PPI              0.473487
# Processor        0.430293
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS         PPI  Processor      Cpu_Brand  HDD  \
# 0   71378.6832            0    1  226.983005        2.3  Intel Core i5    0
# 1   47895.5232            0    0  127.677940        1.8  Intel Core i5    0
# 2   30636.0000            0    0  141.211998        2.5  Intel Core i5    0
# 3  135195.3360            0    1  220.534624        2.7  Intel Core i7    0
# 4   96095.8080            0    1  226.983005        3.1  Intel Core i5    0
#
#    SSD
# 0  128
# 1    0
# 2  256
# 3  512
# 4  256

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R7                1
# Nvidia GeForce GTX1080       1
# AMD Radeon 540               1
# AMD FirePro W4190M           1
# AMD FirePro W6150M           1
# Name: Gpu, Length: 110, dtype: int64

# %%
df['gpu_brand'] = df["Gpu"].apply(lambda x:x.split()[0])

# %%
df['gpu_brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: gpu_brand, dtype: int64

# %%
df = df[df['gpu_brand'] != 'ARM']

# %%
df['gpu_brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# Name: gpu_brand, dtype: int64

# %%
sns.barplot(x=df['gpu_brand'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='gpu_brand', ylabel='Price'>

# %%
df.drop(columns=['Gpu'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  IPS  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           PPI  Processor      Cpu_Brand  HDD  SSD gpu_brand
# 0  226.983005        2.3  Intel Core i5    0  128     Intel
# 1  127.677940        1.8  Intel Core i5    0    0     Intel
# 2  141.211998        2.5  Intel Core i5    0  256     Intel
# 3  220.534624        2.7  Intel Core i7    0  512       AMD
# 4  226.983005        3.1  Intel Core i5    0  256     Intel

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return "MAC"
    else:
        return 'No Os/Linux/Others'

# %%
df['OS'] = df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  IPS  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           PPI  Processor      Cpu_Brand  HDD  SSD gpu_brand  \
# 0  226.983005        2.3  Intel Core i5    0  128     Intel
# 1  127.677940        1.8  Intel Core i5    0    0     Intel
# 2  141.211998        2.5  Intel Core i5    0  256     Intel
# 3  220.534624        2.7  Intel Core i7    0  512       AMD
# 4  226.983005        3.1  Intel Core i5    0  256     Intel
#
#                    OS
# 0                 MAC
# 1                 MAC
# 2  No Os/Linux/Others
# 3                 MAC
# 4                 MAC

# %%
df.drop(columns=['OpSys'],inplace=True)

# %%
sns.barplot(x=df['OS'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  IPS         PPI  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983005
#
#    Processor      Cpu_Brand  HDD  SSD gpu_brand                  OS
# 0        2.3  Intel Core i5    0  128     Intel                 MAC
# 1        1.8  Intel Core i5    0    0     Intel                 MAC
# 2        2.5  Intel Core i5    0  256     Intel  No Os/Linux/Others
# 3        2.7  Intel Core i7    0  512       AMD                 MAC
# 4        3.1  Intel Core i5    0  256     Intel                 MAC

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
X
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  IPS         PPI  \
# 0      Apple           Ultrabook    8    1.37            0    1  226.983005
# 1      Apple           Ultrabook    8    1.34            0    0  127.677940
# 2         HP            Notebook    8    1.86            0    0  141.211998
# 3      Apple           Ultrabook   16    1.83            0    1  220.534624
# 4      Apple           Ultrabook    8    1.37            0    1  226.983005
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.350512
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.053530
# 1300  Lenovo            Notebook    2    1.50            0    0  111.935204
# 1301      HP            Notebook    6    2.19            0    0  100.454670
# 1302    Asus            Notebook    4    2.20            0    0  100.454670
#
# ...

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=2)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from sklearn.svm import SVR

# %% [markdown]
# # Linear Regression

# %%
step1 = ColumnTransformer(transformers= [
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,8,11,12])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1' , step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)
pred  = pipe.predict(X_test)

print(r2_score(y_test,pred))
print(mean_absolute_error(y_test,pred))
# Out:
# 0.813942572564544
# 0.2035797271223238

# %% [markdown]
# # Ridge Regression

# %%
step1 = ColumnTransformer(transformers= [
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,8,11,12])
],remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1' , step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)
pred  = pipe.predict(X_test)

print(r2_score(y_test,pred))
print(mean_absolute_error(y_test,pred))
# Out:
# 0.8167945503948656
# 0.20616085902628273

# %% [markdown]
# # Lasso regression

# %%
step1 = ColumnTransformer(transformers= [
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,8,11,12])
],remainder='passthrough')

step2 = Lasso(alpha=0.001)


pipe = Pipeline([
    ('step1' , step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)
pred  = pipe.predict(X_test)

print(r2_score(y_test,pred))
print(mean_absolute_error(y_test,pred))
# Out:
# 0.8155525957521048
# 0.20473301242766762

# %% [markdown]
# # K-nearest neighbours

# %%
step1 = ColumnTransformer(transformers= [
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,8,11,12])
],remainder='passthrough')

step2 = StandardScaler()

step3 = KNeighborsRegressor()

pipe = Pipeline([
    ('step1' , step1),
    ('step2',step2),
    ('step3',step3)
])

pipe.fit(X_train,y_train)
pred  = pipe.predict(X_test)

print(r2_score(y_test,pred))
print(mean_absolute_error(y_test,pred))
# Out:
# 0.8572745375553039
# 0.1783627037537955

# %% [markdown]
# # Decision Tree

# %%
step1 = ColumnTransformer(transformers= [
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,8,11,12])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=6)

pipe = Pipeline([
    ('step1' , step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)
pred  = pipe.predict(X_test)

print(r2_score(y_test,pred))
print(mean_absolute_error(y_test,pred))
# Out:
# 0.8356776192687639
# 0.18937115944190228

# %% [markdown]
# # Random Forest regressor

# %%
step1 = ColumnTransformer(transformers= [
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,8,11,12])
],remainder='passthrough')

# step2 = RandomForestRegressor(n_estimators=120,max_features=0.15)
step2 = StandardScaler()

step3 = RandomForestRegressor(n_estimators=125,max_features=0.15)

pipe1 = Pipeline([
    ('step1' , step1),
    ('step2',step2),
    ('step3',step3)
])

# pipe = Pipeline([
#     ('step1' , step1),
#     ('step2',step2)
# ])

pipe1.fit(X_train,y_train)
pred  = pipe1.predict(X_test)

print(r2_score(y_test,pred))
print(mean_absolute_error(y_test,pred))
# Out:
# 0.9130733033685867
# 0.13880753897226544

# %% [markdown]
# # SVR

# %%
step1 = ColumnTransformer(transformers= [
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,8,11,12])
],remainder='passthrough')

step2 = SVR(C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1' , step1),
    ('step2',step2)
])


pipe.fit(X_train,y_train)
pred  = pipe.predict(X_test)

print(r2_score(y_test,pred))
print(mean_absolute_error(y_test,pred))
# Out:
# 0.8183870328789952
# 0.19554658028857524

# %% [markdown]
# # XG Boost

# %%
step1 = ColumnTransformer(transformers= [
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,8,11,12])
],remainder='passthrough')

step2 = XGBRegressor(n_estimators=125,max_depth=3,learning_rate=0.4)

pipe = Pipeline([
    ('step1' , step1),
    ('step2',step2)
])


pipe.fit(X_train,y_train)
pred  = pipe.predict(X_test)

print(r2_score(y_test,pred))
print(mean_absolute_error(y_test,pred))
# Out:
# 0.9012845853209068
# 0.14513714321140758

# %% [markdown]
# # Voting Regressor

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import ExtraTreesRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,8,12,11])
],remainder='passthrough')


rf = RandomForestRegressor(n_estimators=120,random_state=3,max_samples=0.8,max_features=0.4,max_depth=20)
gbdt = GradientBoostingRegressor(n_estimators=130,max_features=0.5)
xgb = XGBRegressor(n_estimators=125,learning_rate=0.4,max_depth=20)
et = ExtraTreesRegressor(n_estimators=120,random_state=3,max_samples=0.7,max_features=0.75,max_depth=20)

step2 = VotingRegressor([('rf', rf), ('gbdt', gbdt),('xgb',xgb),('et',et)],weights=[3,1,2,1])

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.9135472246887228
# MAE 0.14079216189824398

# %% [markdown]
# # Stacking

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,8,12,11])
],remainder='passthrough')


estimators = [
    ('rf', RandomForestRegressor(n_estimators=130,random_state=3,max_samples=0.8,max_features=0.4,max_depth=20)),
    ('gbdt',GradientBoostingRegressor(n_estimators=130,max_features=0.7)),
    ('xgb', XGBRegressor(n_estimators=125,learning_rate=0.4,max_depth=15))
]

step2 = StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=50))

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.9113424406615359
# MAE 0.14474192778376216

# %% [markdown]
# # Exporting model

# %%
import pickle
pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe1,open('pipe.pkl','wb'))
